# %%
import pandas

data_frame = pandas.read_csv("all_courses.tsv", sep = "~")
# Out:
#                                             depart  \
# 0                                    Latin (LATIN)
# 1                                    Latin (LATIN)
# 2                                    Latin (LATIN)
# 3                                    Latin (LATIN)
# 4                                    Latin (LATIN)
# 5                                    Latin (LATIN)
# 6                                    Latin (LATIN)
# 7                                    Latin (LATIN)
# 8                                    Latin (LATIN)
# 9                                    Latin (LATIN)
# 10                                   Latin (LATIN)
# 11                                   Latin (LATIN)
# 12                                   Latin (LATIN)
# 13                                   Latin (LATIN)
# 14                                   Latin (LATIN)
# 15                                   Latin (LATIN)
# 16                                   Latin (LATIN)
# ...
